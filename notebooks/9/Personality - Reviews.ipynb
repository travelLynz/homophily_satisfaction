# %%
# %load_ext autoreload
# %autoreload 2
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize
import pandas as pd
import os
import sys
import numpy as np
sys.path.append("../../Code")
import utils
import files as f
import seaborn as sns
import matplotlib.pyplot as plt
import preprocessing as pre
import languages as lang
stopWords = set(stopwords.words('english'))
import profiles
import afinns as af
# Out:
# /Users/lynraybarends/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
def end_review(text):
    terminals ="?!."
    if text[-1] not in terminals:
        return text + "."
    else:
        return text

# %% [markdown]
# # Load Guests, Hosts, Reviews , and reverse reviews

# %%
guests = pd.read_csv(os.path.join('..','2','nr_restrict_guests.csv'), low_memory=False, index_col=0).drop_duplicates(subset="id", keep="last")
hosts = pd.read_csv(os.path.join('..','2','nr_restrict_hosts.csv'), index_col=0)
hosts = hosts[~hosts.index.isnull()]
reviews = pd.read_csv(os.path.join('..','2','nr_restrict_reviews.csv'), index_col=0)

# %%
host_reviews = pd.read_csv(os.path.join('..','2','man_hostReviews.csv'), index_col=0)
host_reviews = host_reviews[host_reviews['reviewer_id'].isin(hosts.id.unique())]

# %%
host_reviews['reviewer_id'] = host_reviews['reviewer_id'].astype(int).astype(str)

# %%
host_reviews = host_reviews[~host_reviews['comments'].isnull()]

# %%
len(guests)
# Out:
# 96255

# %%
len(hosts)
# Out:
# 6924

# %%
guest_reviews_corr = pd.read_csv(os.path.join('..','5','guest_reviews_spell.csv'), index_col=0)

# %%
host_reviews_corr = pd.read_csv(os.path.join('..','5','host_reviews_spell.csv'), index_col=0)

# %%
len(guest_reviews_corr)
# Out:
# 225090

# %%
len(host_reviews_corr)
# Out:
# 36202

# %% [markdown]
# ## Get Personality from all outward reviews

# %%
len(guests.id.unique())
# Out:
# 96255

# %%
len(guests.id)
# Out:
# 96255

# %% [markdown]
# ### Merge All Reviews First

# %%
guests[guests.id == 178500510]
# Out:
# Empty DataFrame
# Columns: [idGuest, id, name, city, ccode, membershipMonth, membershipYear, superhost, verified, description, linkedAccountVerified, schoolInfo, jobInfo, languages, reviewNumber, guideNumber, wishListNumber]
# Index: []

# %%
g_ids = set(guests['id']).union(set(guest_reviews_corr['reviewer_id']))
list_g_ids = list(g_ids)

# %%
guests_full = pd.DataFrame({'id': list_g_ids })

# %%
g_reviews = []
g_num_reviews = []
for g in list_g_ids:
    revs = [end_review(c) for c in guest_reviews_corr[guest_reviews_corr['reviewer_id'] == g]['comments']]
    g_reviews.append(revs)
    g_num_reviews.append(len(revs))

# %% [raw]
# g_reviews = []
# g_num_reviews = []
# for g in guests['id']:
#     revs = [end_review(c) for c in guest_reviews_corr[guest_reviews_corr['reviewer_id'] == g]['comments']]
#     g_reviews.append(revs)
#     g_num_reviews.append(len(revs))

# %%
guests_full['review_text'] = g_reviews
guests_full['num_reviews'] = g_num_reviews

# %%
guests_full.head()
# Out:
#          id                                        review_text  num_reviews
# 0         1  [Great spot. I enjoyed the location and the sp...            2
# 1         3  [Stayin at Asher's Guest Room in his Art Loft ...            1
# 2  40894469  [We had a wonderful stay in New York! Carlinho...            1
# 3  26214407  [Our first airbnb experience was fantastic, al...            1
# 4   2097159  [Thanks Adam, Kristine, and Seth!  While the o...            1

# %%
h_ids = set(hosts['id']).union(set(host_reviews_corr['reviewer_id']))
list_h_ids = list(h_ids)

# %%
hosts_full = pd.DataFrame({'id': list_h_ids })

# %%
h_reviews = []
h_num_reviews = []
for h in list_h_ids :
    revs = [end_review(c) for c in host_reviews_corr[host_reviews_corr['reviewer_id'] == h]['comments']]
    h_reviews.append(revs)
    h_num_reviews.append(len(revs))

# %%
hosts_full['review_text'] = h_reviews
hosts_full['num_reviews'] = h_num_reviews

# %%
guests_full.to_csv('guests_outward_review_full.csv')
hosts_full.to_csv('hosts_outward_review_full.csv')

# %% [markdown]
# # Personality

# %%
guests = pd.read_csv('guests_outward_review_full.csv', index_col=0)

# %%
guest_profile = pd.read_csv('guest_profile_spell.csv', low_memory=False, index_col=0)

# %%
guest_text = guests.join(guest_profile[['id', 'description']].set_index('id'), on='id')

# %%
hosts = pd.read_csv('hosts_outward_review_full.csv', index_col=0)

# %%
host_profile = pd.read_csv('host_profile_spell.csv', low_memory=False, index_col=0)

# %%
host_text = hosts.join(host_profile[['id', 'about']].set_index('id'), on='id')

# %%
all_text = pd.concat([guest_text, host_text.rename(columns={'about':'description'})]).reset_index(drop=True)

# %%
all_text = all_text.drop_duplicates()

# %%
all_text = all_text[(all_text['review_text'] != '[]') |(~all_text['description'].isnull())]

# %%
n_reviews = []
merged_text = []
for _, r in all_text.iterrows():
    if (len(r['review_text']) == 0) and (r['description'].isnull()):
        n_reviews.append(r['num_reviews'])
        merged_text.append(None)
    elif (r['description'] in [np.nan, None]):
        n_reviews.append(r['num_reviews'])
        merged_text.append(r['review_text'])
    elif (r['review_text'] in [np.nan, None]):
        n_reviews.append(1)
        merged_text.append(r['description'])
    else:
        n_reviews.append(r['num_reviews'] + 1)
        merged_text.append(list([r['description']])+(eval(r['review_text']) ) )

# %%
all_text['num_of_texts'] = n_reviews
all_text['merged_texts'] = merged_text

# %%
all_text.to_csv('personality_text.csv')

# %%
all_text['personality'] = [lang.get_personality_metrics(t) for t in all_text['merged_texts']]

# %%
all_text.to_csv('personality.csv')

# %% [markdown]
# ### Hosts

# %%
host_text = hosts_full.join(hosts[['id', 'about']].set_index('id'), on='id')

# %%
n_reviews = []
merged_text = []
for _, r in host_text.iterrows():
    if (len(r['review_text']) == 0) and (r['about'] in [np.nan, None]):
        n_reviews.append(r['num_reviews'])
        merged_text.append(None)
    elif (r['about'] in [np.nan, None]):
        n_reviews.append(r['num_reviews'])
        merged_text.append(r['review_text'])
    elif len(r['review_text']) == 0:
        n_reviews.append(1)
        merged_text.append(r['about'])
    else:
        n_reviews.append(r['num_reviews'] + 1)
        merged_text.append([r['about']]+r['review_text'])

# %%
host_text['num_of_texts'] = n_reviews
host_text['merged_texts'] = merged_text

# %%
host_text.to_csv('hosts_outward_full.csv')

# %%
host_text['personality'] = [lang.get_personality_metrics(t) for t in host_text['merged_texts']]

# %%
host_text.to_csv('host_review_personality.csv')

# %%
pd.options.display.max_colwidth = 10000 # 7118

# %%
a = pd.read_csv('host_review_personality.csv', index_col=0)

# %%
a
# Out:
#              id                                        review_text  \
# 0          7118  ['The guests I met seemed cool and nice, and m...
# 1          7322                                                 []
# 2          7386  ['Bill arrived and left at the times he said h...
# 3          8967  ['It was a please sure to serve Janet here. Th...
# 4          7490  ['Bonnie is an outstanding guest: considerate,...
# 5          7702  ['Fantastic guest! Isis was very easy to commu...
# 6          7989  ['Stephen was a polite, quiet and respectful g...
# 7          8526  ['Great guest !', 'Philippe and his family too...
# 8         18583  ['great. nice, pleasant, easy-going.', 'i woul...
# 9         18946  ['Fantastic! What a terrific family. Their jub...
# 10        30193  ['Adam was great! He left my place in good sha...
# 11        31374  ['They became like daughters to me. I really m...
# 12        21904  ['Pawel and Jola were ideal guests! My apartme...
# 13        32045  ['Joakim was a wonderful guest. He is extremel...
# 14        47727  ["Berris was an amazing guests; they don't com...
# 15         7612  ['Thanks Amit! You guys were great! Come back ...
# 16        56094  ['Wanda was at my New York Apartment over Chri...
# 17        56284  ['The perfect guests, my apt was left in a per...
# 18        59023  ['Having Morgan has been a pleasure!', "It's b...
# 19        61446  ['Great low key guest . Good communication & w...
# 20        65837  ['Bethany and her family were wonderful guests...
# 21        66035  ["Siobhan's parents were just great. It was a ...
# 22        66243  ["Oge was a clean and kind guest... welcome he...
# 23        69942  ['Vey nice and friendly guest.', 'Great guest....
# 24        71876  ['Dorian was a wonderful guest. He and his gir...
# 25        73051  ['Perfect guests!', "Jessica has been a very n...
# 26        62407  ['Samantha is really cool. I enjoyed her visit...
# 27        42032  ['Katherine was a joy to host! A lovely, commu...
# 28        87336  ['Hosting Amandine was really great. We commun...
# 29        63318  ['intelligent guy. Had no problems with him wh...
# ...         ...                                                ...
# 6894  184270933  ['Great guests!', 'great guest welcome back an...
# 6895  184407284  ['Great guest Highly recommended.', 'Great gue...
# 6896  145005520  ['Our first guests! Very nice!))).', 'We enjoy...
# 6897  184596187  ['Great guy. 10/10... thanks!!', 'Anthony was ...
# 6898  184861905  ['Evan was a great guest. He and his girlfrien...
# 6899  111984972  ['Milla was exceptionally respectful, clean, a...
# 6900  173369078  ['Very good guest, definitely recommend.', 'Go...
# 6901  183571032                                                 []
# 6902  184905240  ['Monika was a very sweet and wonderful guest....
# 6903  184523531  ['Spark was a perfect guest! He is very kind a...
# 6904  184996325  ['It was a pleasure to host Dimitry. He is def...
# 6905   52525653  ['Great guests would highly recommend them. Ef...
# 6906  111486188  ['It was very nice meeting Jeanette & I recomm...
# 6907  146182000  ['That was pleasure to have Nehal and her frie...
# 6908    3268993  ['Super cool & friendly guest! Enjoyed hosting...
# 6909   99556104  ['Turcut was clean, courteous, and all around ...
# 6910  186111724  ['great couple fun to have stay with us very c...
# 6911   46101534  ['It was great having Thomas as an Airbnb gues...
# 6912  126034120  ["Rama is nice, courteous and polite. It was g...
# 6913  186655402  ['Really chill. There for two nights and one d...
# 6914  186905487  ['Thomas was a fine guest...he needed a place ...
# 6915  111192111  ['Gael was amazing, and had so many cool stori...
# 6923            4                                                NaN
#
#       num_of_texts                                       merged_texts  \
# 0               22  ["Professional Designer/Artist working in Thea...
# 1                1  I'm an artist, writer, traveler, and a native ...
# 2               45  ['wunderlustful itinerant smarty pants ... coo...
# 3               50  ['I used to work for a financial industry but ...
# 4               98  ["Welcome to family life with my oldest two aw...
# 5               36  ['I am a New Yorker who loves to travel.', 'Fa...
# 6              113  ["I am an educator and researcher and I've wor...
# 7               33  ['I was born and raised in Arizona and have li...
# 8               45  ['Hey, I am John - Fun, nice, educated, clean,...
# 9              119  ['Raised in Europe and Asia I love to host int...
# 10              46  ['I am a spirit-minded shoe model and alternat...
# 11              23  ["I'm from New York. I love to travel, been pr...
# 12              17  ["I am an industrial designer and native new y...
# 13              38  ["I'm a citizen of the world.  I love to trave...
# 14              60  ['My reviews are a more accurate description o...
# 15             144  ['I am a very positive person who strives to e...
# 16               9  ["I'm a long time television news anchor. I tr...
# 17              14  ['Italian, I have been living in ny  for the l...
# 18              12  ['I am dancer, choreographer, Pilates teacher ...
# 19              36  [' Interior Designer from NYC & Miami Beach 56...
# 20              99  ["My husband and I are media professionals who...
# 21              45  ['I am a video artist. I have lived in NY for ...
# 22               8  ['Hi my name is Enzo and this was my fathers l...
# 23              32  ['I am host and a traveler who likes to meet n...
# 24             100  ['Fun couple. Looking forward to meeting you a...
# 25              44  ['I am a communication marketing publicity con...
# 26             116  [' I am a real east village writer and perform...
# 27              45  ["I'm an arts consultant, personal trainer and...
# 28              14  ['Calm, sane, world class, living in NYC for 2...
# 29              22  ['Shave a monkey and put her in a tutu and you...
# ...            ...                                                ...
# 6894             4  ['Great guests!', 'great guest welcome back an...
# 6895             2  ['Great guest Highly recommended.', 'Great gue...
# 6896             7  ['Lifeloving, LOVE to traveling . Believe in g...
# 6897             5  ["Hi, I'm Tommy  ... I am a young writer based...
# 6898             6  ['Evan was a great guest. He and his girlfrien...
# 6899             3  ['I am a professor, traveling for research and...
# 6900             4  ['Very good guest, definitely recommend.', 'Go...
# 6901             1  Hardworking professional who is trying to make...
# 6902             1  ['Monika was a very sweet and wonderful guest....
# 6903             3  ["Comfortable, spacious & clean private room i...
# 6904             6  ["My name is Brunno and New York has been my h...
# 6905             4  ['Great guests would highly recommend them. Ef...
# 6906             7  ['Married Canadian software professional livin...
# 6907             2  ['That was pleasure to have Nehal and her frie...
# 6908             7  ["Los Angeles native currently living in New Y...
# 6909             2  ['IT consultant born and raised in NYC', 'Turc...
# 6910             5  ['Brazilian, Graduated in Gastronomy, I speak ...
# 6911             4  ['Quiet, simple college student interested in ...
# 6912             3  ["Rama is nice, courteous and polite. It was g...
# 6913             1  ['Really chill. There for two nights and one d...
# 6914             2  ['Thomas was a fine guest...he needed a place ...
# 6915             2  ['Gael was amazing, and had so many cool stori...
# 6916             6  ['Nice and helpful person', 'Very quiet, easy-...
# 6917             3  ['Great guests! Welcome back anytime.', 'Nice ...
# 6918             4  ['Great guests.', 'Wonderful guests and we had...
# 6919             3  ['Very humble easy to get along with ', 'John ...
# 6920             3  ["I've often thought that one of the best thin...
# 6921             4  ['Great guest!', 'Jason himself was okay thoug...
# 6922            13  ['I’m freelancer ', '| ★★★★★ |.', '| ★★★★★ |.'...
# 6923             4  ['I had an awesome time hosting them! They wer...
#
#                                             personality
# 0     {'avg_wc': 14.272727272727273, 'avg_word_len':...
# 1     {'avg_wc': 0.7662337662337663, 'avg_word_len':...
# 2     {'avg_wc': 21.555555555555557, 'avg_word_len':...
# 3     {'avg_wc': 23.62, 'avg_word_len': 3.9974597798...
# 4     {'avg_wc': 37.60204081632653, 'avg_word_len': ...
# 5     {'avg_wc': 18.63888888888889, 'avg_word_len': ...
# 6     {'avg_wc': 41.16814159292036, 'avg_word_len': ...
# 7     {'avg_wc': 14.787878787878787, 'avg_word_len':...
# 8     {'avg_wc': 29.0, 'avg_word_len': 4.31800766283...
# 9     {'avg_wc': 52.705882352941174, 'avg_word_len':...
# 10    {'avg_wc': 25.47826086956522, 'avg_word_len': ...
# 11    {'avg_wc': 30.304347826086957, 'avg_word_len':...
# 12    {'avg_wc': 26.470588235294116, 'avg_word_len':...
# 13    {'avg_wc': 31.289473684210527, 'avg_word_len':...
# 14    {'avg_wc': 29.35, 'avg_word_len': 4.4690516751...
# 15    {'avg_wc': 13.659722222222221, 'avg_word_len':...
# 16    {'avg_wc': 19.88888888888889, 'avg_word_len': ...
# 17    {'avg_wc': 35.785714285714285, 'avg_word_len':...
# 18    {'avg_wc': 30.833333333333332, 'avg_word_len':...
# 19    {'avg_wc': 24.416666666666668, 'avg_word_len':...
# 20    {'avg_wc': 26.03030303030303, 'avg_word_len': ...
# 21    {'avg_wc': 41.6, 'avg_word_len': 4.15010683760...
# 22    {'avg_wc': 41.25, 'avg_word_len': 4.3424242424...
# 23    {'avg_wc': 13.0, 'avg_word_len': 4.23076923076...
# 24    {'avg_wc': 46.34, 'avg_word_len': 4.4924471299...
# 25    {'avg_wc': 20.613636363636363, 'avg_word_len':...
# 26    {'avg_wc': 44.5, 'avg_word_len': 4.27624951569...
# 27    {'avg_wc': 26.42222222222222, 'avg_word_len': ...
# 28    {'avg_wc': 26.428571428571427, 'avg_word_len':...
# 29    {'avg_wc': 57.27272727272727, 'avg_word_len': ...
# ...                                                 ...
# 6894  {'avg_wc': 4.25, 'avg_word_len': 5.70588235294...
# 6895  {'avg_wc': 4.0, 'avg_word_len': 6.75, 'avg_sen...
# 6896  {'avg_wc': 8.285714285714286, 'avg_word_len': ...
# 6897  {'avg_wc': 18.2, 'avg_word_len': 4.12087912087...
# 6898  {'avg_wc': 18.833333333333332, 'avg_word_len':...
# 6899  {'avg_wc': 18.333333333333332, 'avg_word_len':...
# 6900  {'avg_wc': 19.0, 'avg_word_len': 4.60526315789...
# 6901  {'avg_wc': 0.808695652173913, 'avg_word_len': ...
# 6902  {'avg_wc': 33.0, 'avg_word_len': 4.24242424242...
# 6903  {'avg_wc': 71.33333333333333, 'avg_word_len': ...
# 6904  {'avg_wc': 22.166666666666668, 'avg_word_len':...
# 6905  {'avg_wc': 11.5, 'avg_word_len': 4.82608695652...
# 6906  {'avg_wc': 13.142857142857142, 'avg_word_len':...
# 6907  {'avg_wc': 13.5, 'avg_word_len': 4.59259259259...
# 6908  {'avg_wc': 23.142857142857142, 'avg_word_len':...
# 6909  {'avg_wc': 13.5, 'avg_word_len': 4.77777777777...
# 6910  {'avg_wc': 10.2, 'avg_word_len': 4.86274509803...
# 6911  {'avg_wc': 15.75, 'avg_word_len': 4.7142857142...
# 6912  {'avg_wc': 15.0, 'avg_word_len': 3.82222222222...
# 6913  {'avg_wc': 21.0, 'avg_word_len': 5.04761904761...
# 6914  {'avg_wc': 28.5, 'avg_word_len': 4.29824561403...
# 6915  {'avg_wc': 17.0, 'avg_word_len': 3.94117647058...
# 6916  {'avg_wc': 6.0, 'avg_word_len': 4.333333333333...
# 6917  {'avg_wc': 4.0, 'avg_word_len': 5.333333333333...
# 6918  {'avg_wc': 3.25, 'avg_word_len': 6.15384615384...
# 6919  {'avg_wc': 13.333333333333334, 'avg_word_len':...
# 6920  {'avg_wc': 44.666666666666664, 'avg_word_len':...
# 6921  {'avg_wc': 13.5, 'avg_word_len': 4.66666666666...
# 6922  {'avg_wc': 1.2307692307692308, 'avg_word_len':...
# 6923  {'avg_wc': 25.25, 'avg_word_len': 4.3762376237...
#
# [6924 rows x 7 columns]

# %% [markdown]
# ## Classify values

# %%
all_personality
# Out:
#                id                                       merged_texts  \
# 0               1  [I live with my wife who is a doctor at Stanfo...
# 1               3  [I am originally from NY, and have been living...
# 2        40894469  ['We had a wonderful stay in New York! Carlinh...
# 3        26214407  [Living in the beautiful city of Winchester in...
# 4         2097159  ["Thanks Adam, Kristine, and Seth!  While the ...
# 5         2097168  ["Matt was extremely proactive about making su...
# 6        63963154  ["A very nice apartment. Clean and comfortable...
# 7         4194323  ['Eddie’s place is fantastic - I would definit...
# 8        63963158  [Professional. Like to embrace local culture w...
# 9       156237850  ['Thanks! great communication and terrific loc...
# 10       30408734  ['Very good host. He was the one that receive ...
# 11        2097183  [I am a full time working mum, with three adul...
# 12       35651614  ['Max and Alia were kind and generous hosts wh...
# 13        8388639  ["A really great place to stay at in New York....
# 14       73400356  ['We had a nice stay.  Asif was very good at c...
# 15       50331691  [I’m a bilingual (French/English) Montrealer p...
# 16        6291502  [Just one life so I enjoy it :), No regrets !J...
# 17        9437234          ['Very nice place, central in New York.']
# 18        4194356  ["A great location for exploring the area!  We...
# 19             56  [New York transplant to San Francisco and lovi...
# 20       10485817  [We are Jac and Marlies. We are in our early s...
# 21       60817467  ["This is a great place - it's quite large for...
# 22      159383614  ['Thanks Daniel for hosting me.Everything was ...
# 23      158335043  ['Location is excellent, subway is a block awa...
# 24             72  ['Comfortable, clean and bright stylish apartm...
# 25       22020175  ['We stayed with Daniel when we had a long wee...
# 26       69206104  ['Exactly as pictured and very clean.  Shawn i...
# 27       77594718  [More than traveling to elegant places, I like...
# 28       48234603  ['This is a very convenient location for us. L...
# 29      155189359  [25 year old personal trainer and Pilates inst...
# ...           ...                                                ...
# 23        0.062963  0.000000  0.103704        0.000000     93.571429
# 24        0.098361  0.000000  0.147541        0.000000     98.333333
# 25        0.084399  0.000000  0.079284        0.000000    139.571429
# 26        0.133333  0.000000  0.111111        0.000000     73.000000
# 27        0.115942  0.065217  0.072464        0.210145    123.833333
# 28        0.120130  0.003247  0.100649        0.000000     92.500000
# 29        0.056818  0.045455  0.113636        0.227273     84.333333
# ...            ...       ...       ...             ...           ...
# 218027         NaN       NaN       NaN             NaN           NaN
# 218028         NaN       NaN       NaN             NaN           NaN
# 218029         NaN       NaN       NaN             NaN           NaN
# 218030         NaN       NaN       NaN             NaN           NaN
# 218031         NaN       NaN       NaN             NaN           NaN
# 218033         NaN       NaN       NaN             NaN           NaN
# 218034         NaN       NaN       NaN             NaN           NaN
# 218035         NaN       NaN       NaN             NaN           NaN
# 218036         NaN       NaN       NaN             NaN           NaN
# 218037         NaN       NaN       NaN             NaN           NaN
# 218038         NaN       NaN       NaN             NaN           NaN
# 218039         NaN       NaN       NaN             NaN           NaN
# 218040         NaN       NaN       NaN             NaN           NaN
# 218042         NaN       NaN       NaN             NaN           NaN
# 218045         NaN       NaN       NaN             NaN           NaN
# 218046         NaN       NaN       NaN             NaN           NaN
# 218047         NaN       NaN       NaN             NaN           NaN
# 218048         NaN       NaN       NaN             NaN           NaN
# 218049         NaN       NaN       NaN             NaN           NaN
# 218050         NaN       NaN       NaN             NaN           NaN
# 218051         NaN       NaN       NaN             NaN           NaN
# 218052         NaN       NaN       NaN             NaN           NaN
# 218053         NaN       NaN       NaN             NaN           NaN
# 218054         NaN       NaN       NaN             NaN           NaN
# 218055         NaN       NaN       NaN             NaN           NaN
# 218056         NaN       NaN       NaN             NaN           NaN
# 218059         NaN       NaN       NaN             NaN           NaN
# 218062         NaN       NaN       NaN             NaN           NaN
# 218063         NaN       NaN       NaN             NaN           NaN
# 218064         NaN       NaN       NaN             NaN           NaN
#
#             avg_wc  avg_word_len   capital    ...     positive_words  \
# 0        17.333333      4.442308  0.057692    ...           0.134615
# 1        94.000000      4.340426  0.047872    ...           0.037234
# 2         0.806306      1.000000  0.039106    ...           0.000000
# 3       161.500000      4.343653  0.009288    ...           0.055728
# 4         0.795594      1.000000  0.027692    ...           0.000000
# 5         0.782414      1.000000  0.032381    ...           0.000000
# 6         0.770000      1.000000  0.038961    ...           0.000000
# 7         0.790663      1.000000  0.019048    ...           0.000000
# 8        24.500000      4.183673  0.000000    ...           0.122449
# 9         0.815534      1.000000  0.023810    ...           0.000000
# 10        0.776271      1.000000  0.019651    ...           0.000000
# 11       71.000000      4.457746  0.028169    ...           0.035211
# 12        0.792642      1.000000  0.025316    ...           0.000000
# 13        0.777174      1.000000  0.062937    ...           0.000000
# 14        0.777778      1.000000  0.022556    ...           0.000000
# 15       17.500000      5.171429  0.028571    ...           0.114286
# 16       17.000000      4.235294  0.058824    ...           0.176471
# 17        0.756098      1.000000  0.096774    ...           0.000000
# 18        0.778970      1.000000  0.026171    ...           0.000000
# 19       32.250000      4.647287  0.007752    ...           0.131783
# 20      131.500000      4.266160  0.011407    ...           0.041825
# 21        0.772321      1.000000  0.017341    ...           0.000000
# 22        0.796053      1.000000  0.028926    ...           0.000000
# 23        0.794118      1.000000  0.044444    ...           0.000000
# 24        0.813333      1.000000  0.016393    ...           0.000000
# 25        0.786720      1.000000  0.030691    ...           0.000000
# 26        0.796460      1.000000  0.022222    ...           0.000000
# 27       69.000000      4.246377  0.043478    ...           0.050725
# 28        0.810526      1.000000  0.022727    ...           0.000000
# 29       44.000000      4.715909  0.022727    ...           0.056818
# ...            ...           ...       ...    ...                ...
# 218027         NaN           NaN       NaN    ...                NaN
# 218028         NaN           NaN       NaN    ...                NaN
# 218029         NaN           NaN       NaN    ...                NaN
# 218030         NaN           NaN       NaN    ...                NaN
# 218031         NaN           NaN       NaN    ...                NaN
# 218033         NaN           NaN       NaN    ...                NaN
# 218034         NaN           NaN       NaN    ...                NaN
# 218035         NaN           NaN       NaN    ...                NaN
# 218036         NaN           NaN       NaN    ...                NaN
# 218037         NaN           NaN       NaN    ...                NaN
# 218038         NaN           NaN       NaN    ...                NaN
# 218039         NaN           NaN       NaN    ...                NaN
# 218040         NaN           NaN       NaN    ...                NaN
# 218042         NaN           NaN       NaN    ...                NaN
# 218045         NaN           NaN       NaN    ...                NaN
# 218046         NaN           NaN       NaN    ...                NaN
# 218047         NaN           NaN       NaN    ...                NaN
# 218048         NaN           NaN       NaN    ...                NaN
# 218049         NaN           NaN       NaN    ...                NaN
# 218050         NaN           NaN       NaN    ...                NaN
# 218051         NaN           NaN       NaN    ...                NaN
# 218052         NaN           NaN       NaN    ...                NaN
# 218053         NaN           NaN       NaN    ...                NaN
# 218054         NaN           NaN       NaN    ...                NaN
# 218055         NaN           NaN       NaN    ...                NaN
# 218056         NaN           NaN       NaN    ...                NaN
# 218059         NaN           NaN       NaN    ...                NaN
# 218062         NaN           NaN       NaN    ...                NaN
# 218063         NaN           NaN       NaN    ...                NaN
# 218064         NaN           NaN       NaN    ...                NaN
#
#         pronouns      self  swear  tentative        to  unique_words  \
# 0       0.115385  0.000000    0.0   0.000000  0.019231      0.846154
# 1       0.074468  0.000000    0.0   0.021277  0.015957      0.686170
# 2       0.039106  0.000000    0.0   0.000000  0.000000      0.128492
# 3       0.040248  0.003096    0.0   0.012384  0.030960      0.578947
# 4       0.027692  0.000000    0.0   0.000000  0.000000      0.041538
# 5       0.034286  0.000000    0.0   0.000000  0.000000      0.047619
# 6       0.025974  0.000000    0.0   0.000000  0.000000      0.285714
# 7       0.013333  0.000000    0.0   0.000000  0.000000      0.045714
# 8       0.040816  0.000000    0.0   0.000000  0.102041      0.795918
# 9       0.023810  0.000000    0.0   0.000000  0.000000      0.250000
# 10      0.015284  0.000000    0.0   0.000000  0.000000      0.054585
# 11      0.112676  0.000000    0.0   0.000000  0.021127      0.633803
# 12      0.025316  0.000000    0.0   0.000000  0.000000      0.101266
# 13      0.048951  0.000000    0.0   0.000000  0.000000      0.167832
# 14      0.022556  0.000000    0.0   0.000000  0.000000      0.157895
# 7       0.131429  0.000000  0.000000
# 8       0.163265  0.000000  0.000000
# 9       0.119048  0.000000  0.000000
# 10      0.117904  0.000000  0.000000
# 11      0.161972  0.035211  0.000000
# 12      0.092827  0.000000  0.000000
# 13      0.160839  0.000000  0.000000
# 14      0.127820  0.000000  0.000000
# 15      0.142857  0.028571  0.000000
# 16      0.117647  0.000000  0.000000
# 17      0.161290  0.000000  0.000000
# 18      0.123967  0.000000  0.000000
# 19      0.139535  0.003876  0.003876
# 20      0.174905  0.053232  0.000000
# 21      0.132948  0.000000  0.000000
# 22      0.136364  0.000000  0.000000
# 23      0.125926  0.000000  0.000000
# 24      0.172131  0.000000  0.000000
# 25      0.156010  0.000000  0.000000
# 26      0.133333  0.000000  0.000000
# 27      0.152174  0.000000  0.021739
# 28      0.113636  0.000000  0.000000
# 29      0.136364  0.011364  0.000000
# ...          ...       ...       ...
# 218027       NaN       NaN       NaN
# 218028       NaN       NaN       NaN
# 218029       NaN       NaN       NaN
# 218030       NaN       NaN       NaN
# 218031       NaN       NaN       NaN
# 218033       NaN       NaN       NaN
# 218034       NaN       NaN       NaN
# 218035       NaN       NaN       NaN
# 218036       NaN       NaN       NaN
# 218037       NaN       NaN       NaN
# 218038       NaN       NaN       NaN
# 218039       NaN       NaN       NaN
# 218040       NaN       NaN       NaN
# 218042       NaN       NaN       NaN
# 218045       NaN       NaN       NaN
# 218046       NaN       NaN       NaN
# 218047       NaN       NaN       NaN
# 218048       NaN       NaN       NaN
# 218049       NaN       NaN       NaN
# 218050       NaN       NaN       NaN
# 218051       NaN       NaN       NaN
# 218052       NaN       NaN       NaN
# 218053       NaN       NaN       NaN
# 218054       NaN       NaN       NaN
# 218055       NaN       NaN       NaN
# 218056       NaN       NaN       NaN
# 218059       NaN       NaN       NaN
# 218062       NaN       NaN       NaN
# 218063       NaN       NaN       NaN
# 218064       NaN       NaN       NaN
#
# [216836 rows x 30 columns]

# %%
personality_keys = ['adjectives', 'adverbs', 'articles', 'avg_long_words', 'avg_sent_len', 'avg_wc', 'avg_word_len', 'capital', 'conj', 'formality', 'i', 'interjections', 'modal', 'negations',\
                   'negative_words', 'nouns', 'other_pro', 'pos_count', 'positive_words',\
                   'pronouns', 'self', 'swear', 'tentative', 'to', 'unique_words', 'verbs',\
                   'we', 'you']

# %%
vals = {k:[] for k in personality_keys}
for i, r in all_text.iterrows():
    for k in personality_keys:
        vals[k].append(r['personality'][k] if r['personality'] not in [np.nan, None] else np.nan)

# %%
for v in vals.keys():
    all_text[v] = vals[v]
# Out:
# /Users/lynraybarends/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
all_personality = all_text[['id', 'merged_texts']].join(pd.DataFrame.from_records([{j:np.nan for j in personality_keys} if i == None else i for i in all_text['personality']]))

# %%
swear = []
for i, r in all_text.iterrows(): 
    text = str(" ".join(r['merged_texts']))
#     sent_token_text = sent_tokenize(text)
    token_text = utils.tokenize(text)
    swear.append(np.sum([1 for t in token_text if t.lower() in swear] if (len(token_text) == 0) else 0))

# %%
pd.options.display.max_colwidth = 500

# %%
swear = set(['fuck', 'shit', 'twat', 'bloody', 'cunt', 'bitch'])

# %%
all_text.to_csv("personality_raw.csv")

# %%
all_text = pd.read_csv('personality_raw.csv', index_col=0)

# %%
all_text[]
# Out:
#                  id    num_reviews   num_of_texts     adjectives  \
# count  2.168360e+05  216836.000000  216836.000000  216823.000000
# mean   4.916303e+07       1.205021       1.467916       0.099805
# std    4.733876e+07       3.161567       3.224241       0.027880
# min    1.000000e+00       0.000000       1.000000       0.000000
# 25%    1.073555e+07       1.000000       1.000000       0.084567
# 50%    3.269430e+07       1.000000       1.000000       0.099010
# 75%    7.469016e+07       1.000000       2.000000       0.113565
# max    1.927242e+08     244.000000     245.000000       1.000000
#
#              adverbs       articles  avg_long_words   avg_sent_len  \
# count  216823.000000  216823.000000   216823.000000  216834.000000
# mean        0.017415       0.093245        0.051070      93.976363
# std         0.032079       0.026559        0.091196      48.434985
# min         0.000000       0.000000        0.000000       1.000000
# 25%         0.000000       0.078652        0.000000      63.000000
# 50%         0.000000       0.093151        0.000000      85.777778
# 75%         0.017544       0.108108        0.111748     115.666667
# max         1.000000       0.375000        1.000000    1930.000000
#
#               avg_wc   avg_word_len     ...            pronouns  \
# count  216823.000000  216823.000000     ...       216823.000000
# mean       15.009251       1.913292     ...            0.049608
# std        31.178844       1.542395     ...            0.048618
# min         0.571429       1.000000     ...            0.000000
# 25%         0.784314       1.000000     ...            0.023256
# 50%         0.797101       1.000000     ...            0.034014
# 75%        12.500000       3.962963     ...            0.057554
# max       689.000000      12.000000     ...            1.000000
#
#                 self          swear      tentative             to  \
# count  216823.000000  216823.000000  216823.000000  216823.000000
# mean        0.000192       0.003759       0.002226       0.007594
# std         0.001541       0.065420       0.006526       0.016211
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         0.142857       4.000000       0.200000       0.333333
#
#         unique_words          verbs             we            you  swear_words
# count  216823.000000  216823.000000  216823.000000  216823.000000     216836.0
# mean        0.308749       0.142429       0.002784       0.001459          0.0
# std         0.282593       0.031719       0.009275       0.005643          0.0
# min         0.001397       0.000000       0.000000       0.000000          0.0
# 25%         0.089849       0.123077       0.000000       0.000000          0.0
# 50%         0.167832       0.137143       0.000000       0.000000          0.0
# 75%         0.583333       0.157742       0.000000       0.000000          0.0
# max         1.000000       0.666667       0.181818       0.250000          0.0
#
# [8 rows x 32 columns]

# %%
all_text_stripped = all_text[['id','merged_texts', 'avg_sent_len', 'capital', 'formality', 'i', 'pronouns', 'unique_words', 'verbs']]

# %%
all_text_stripped[all_text_stripped.formality > 500]
# Out:
#                id                                       merged_texts  \
# 43       10485919  ["Carol and Marc are amazing hosts: they made ...
# 120     127926727  ["It's the first time i use Airbnb and i reall...
# 227      27263879  ['Eric’s place has many issues which are very ...
# 326      28312970  ["Jernee and Seth were great hosts. The descri...
# 1109     30414039  ["Allison was flexible in terms of arrival and...
# 1129     35657019  ["Lexi's apartment was just as described - cha...
# 1675     57679769  ["The charming East Village Studio was exactly...
# 1716    160440412  ['Great size apartment. Perfect location for w...
# 1899     34612187  ['The apartment itself was basically good and ...
arrived, but was very positive throughout the process. I thank her for keeping my apartment in such good condition and welcome her to come back and stay again.\', \'Scott was a great communicator and left the apartment in perfect condition. I welcome him back anytime.\', \'Great guests! Would welcome them again!\', \'Great guests! Left the place in tip top shape. Welcome to come back again!\', "Oriol stayed at my apartment for a few nights over the weekend. He was a great guest and left the apartment in excellent condition. He\'s welcome back anytime.", \'A+ guest, easy communication and left the apartment in perfect condition.\', \'A+ Guests, welcome back anytime.\', \'Easy guests, welcome back anytime.\', "Mandira stayed at my apartment for about two weeks while I was out of town. She requested a discount on her stay which I honored despite not usually doing so since I was already offering the cheapest rates in the neighborhood. Overall the apartment was treated well, but for the price they paid they had very high expectations and got in touch with me many times with various issues that I felt could have easily been solved on their own. Ex. My cleaner forgot to remove some food from the fridge from my last guests and they were concerned with the smell. She also commented on the cleanliness of the apartment, stating things were dusty. This being NYC, things get dusty in a matter of hours so of course over a two week stay dust will have accumulated. I provided a refund for half of the cleaning fee to make up for it. I\'d still recommend them as guests overall.", \'Easy guests, good communication and left the apartment very clean.\', \'Easy guests! Left the apartment in excellent condition. Highly recommended!\', \'Easy guests! Left my place in perfect condition. Highly recommend!\']'

# %%
"".join(all_text_stripped[all_text_stripped.id == 178295576]['merged_texts'])
# Out:
# "['THIS PLACE WAS GREAT FOR IT 2 BE MY FIRST TIME I HAD RE TIME OF MY LIFE... IT WAS VERY CLEAN AND SPACIOUS I WAS ABL TO COOK AND SHOWER COMFORTABLY..... THE HOST WAS VERY RESPECTFUL AND UNDERSTANDING WITH ME..... I LOVE DENIS HOME AS IF IT WAS MY OWN .... NEXT TIME I USED THIS APP DENIS WILL BE THE FIRST HOUSE I HOPE POP UP AND I RESERVE AGAIN.']"

# %%
reviews.index
# Out:
# Int64Index([   203,    204,    205,    206,    207,    208,    209,    210,
#                211,    212,
#             ...
#             428579, 428918, 429333, 429543, 430047, 430814, 431090, 431475,
#             431702, 432140],
#            dtype='int64', length=215960)

# %%
reviews = reviews.join(all_text_stripped[['id', 'formality']].set_index('id'), on='reviewer_id').rename(columns={'formality': 'guest_formality'})

# %%
reviews = reviews.join(all_text_stripped[['id', 'formality']].set_index('id'), on='recipient_id').rename(columns={'formality': 'host_formality'})

# %%
reviews['formality_difference'] = reviews['host_formality'] - reviews['guest_formality']

# %%
reviews[['id', 'formality_difference', 'formality_difference_abs']].to_csv('formality_diff.csv')

# %%
all_text_stripped
# Out:
#                id                                       merged_texts  \
# 0               1  ['I live with my wife who is a doctor at Stanf...
# 1               3  ['I am originally from NY, and have been livin...
# 2        40894469  ['We had a wonderful stay in New York! Carlinh...
# 3        26214407  ['Living in the beautiful city of Winchester i...
# 4         2097159  ["Thanks Adam, Kristine, and Seth!  While the ...
# 5         2097168  ["Matt was extremely proactive about making su...
# 6        63963154  ["A very nice apartment. Clean and comfortable...
# 7         4194323  ['Eddie’s place is fantastic - I would definit...
# 8        63963158  ['Professional. Like to embrace local culture ...
# 9       156237850  ['Thanks! great communication and terrific loc...
# 10       30408734  ['Very good host. He was the one that receive ...
# 218036  0.236842        0.052632  0.078947      0.947368  0.131579
# 218037  0.174497        0.147651  0.053691      0.677852  0.147651
# 218038  0.158333        0.058333  0.091667      0.750000  0.150000
# 218039  0.168919        0.101351  0.067568      0.554054  0.135135
# 218040  0.173077        0.057692  0.067308      0.740385  0.211538
# 218042  0.154519        0.087464  0.075802      0.370262  0.209913
# 218045  0.185714        0.100000  0.157143      0.785714  0.242857
# 218046  0.200000        0.200000  0.000000      1.000000  0.200000
# 218047  0.198198        0.117117  0.081081      0.657658  0.189189
# 218048  0.250000        0.000000  0.500000      1.000000  0.000000
# 218049  0.161905        0.076190  0.114286      0.780952  0.142857
# 218050  0.595796        0.000000  0.025826      0.015616  0.115916
# 218051  0.222222        0.111111  0.055556      0.888889  0.222222
# 218052  0.203911        0.089385  0.083799      0.606145  0.156425
# 218053  0.184211        0.078947  0.105263      0.868421  0.157895
# 218054  0.613824        0.000000  0.024793      0.020285  0.119459
# 218055  0.185083        0.143646  0.096685      0.392265  0.185083
# 218056  0.196078        0.098039  0.039216      0.745098  0.235294
# 218059  0.160377        0.066038  0.066038      0.707547  0.169811
# 218062  0.297297        0.054054  0.135135      0.891892  0.135135
# 218063  0.166667        0.106061  0.075758      0.833333  0.227273
# 218064  0.115702        0.066116  0.115702      0.710744  0.190083
#
# [216836 rows x 13 columns]

# %%
def classify(x, m, s):
    upper_thresh = m+s
    lower_thresh = m-s
    if x >= upper_thresh:
        return 'H'
    elif x > m:
        return 'h'
    elif x <= lower_thresh:
        return 'L'
    elif x < m:
        return "l"
    else:
        return 'm'

# %%
def classify_dimensions(tbl):
    result = pd.DataFrame({"id":tbl['id']})
    
    for c in tbl.drop('id', axis=1).columns :
        classes = []
        mean = np.mean(tbl[c])
        stddev = np.std(tbl[c])
        classes = tbl[c].map(lambda x: classify(x, mean, stddev))
        result[c] = classes
    return result

# %%
class_personality = classify_dimensions(all_text_stripped)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-2dae96a698c2> in <module>()
# ----> 1 class_personality = classify_dimensions(all_text_stripped)
#
# <ipython-input-6-1b1729cf0bc9> in classify_dimensions(tbl)
#       4     for c in tbl.drop('id', axis=1).columns :
#       5         classes = []
# ----> 6         mean = np.mean(tbl[c])
#       7         stddev = np.std(tbl[c])
#       8         classes = tbl[c].map(lambda x: classify(x, mean, stddev))
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    2952             pass
#    2953         else:
# -> 2954             return mean(axis=axis, dtype=dtype, out=out, **kwargs)
#    2955
#    2956     return _methods._mean(a, axis=axis, dtype=dtype,
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#    6340                                       skipna=skipna)
#    6341         return self._reduce(f, name, axis=axis, skipna=skipna,
# -> 6342                             numeric_only=numeric_only)
#    6343
#    6344     return set_function_name(stat_func, name, cls)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    2379                                           'numeric_only.'.format(name))
#    2380             with np.errstate(all='ignore'):
# -> 2381                 return op(delegate, skipna=skipna, **kwds)
#    2382
#    2383         return delegate._reduce(op=op, name=name, axis=axis, skipna=skipna,
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      60             try:
#      61                 with np.errstate(invalid='ignore'):
# ---> 62                     return f(*args, **kwargs)
#      63             except ValueError as e:
#      64                 # we want to transform an object array
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     117                         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     118                 else:
# --> 119                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     120             except Exception:
#     121                 try:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in nanmean(values, axis, skipna)
#     310         dtype_count = dtype
#     311     count = _get_counts(mask, axis, dtype=dtype_count)
# --> 312     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     313
#     314     if axis is not None and getattr(the_sum, 'ndim', False):
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims)
#      30
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 32     return umr_sum(a, axis, dtype, out, keepdims)
#      33
#      34 def _prod(a, axis=None, dtype=None, out=None, keepdims=False):
#
# KeyboardInterrupt:

# %%
personalities = {
    'neurotism': {
        'i': 'h',
        'neg_words': 'h',
        'pos_words': 'l',
        'articles': 'l',
        'we': 'l',
        'negations': 'h',
        'self': 'h',
        'preps': 'l'
    },
    'extraversion': {
        'positive_words': 'h',
        'i': 'h',
        #High number of verbs,adverbs,pronouns,
        'negative_words': 'l',
        'negations': 'l',
        'avg_sent_len': 'l',
        'articles': 'l',
        'unique_words': 'l',
        'pos_count': 'l',
        'formality': 'l',
        'we': 'h',
        'self': 'h'
        
    },
    'openness': {
        'unique_words': 'h',
        'avg_long_words': 'h',
        'tentative': 'h', 
        'i': 'l',
        #low number of present tense words,
        'articles': 'h',
        'you': 'h',
        'swear':'h',
        'self': 'l',
        'preps': 'l'
    },
    'agreeableness': {
        'positive_words': 'h',
        'negative_words': 'l',
        'negations': 'l',
        'i': 'h',
        'articles': 'h',
        'we': 'h',
        'you': 'l',
        'swear':'l',
        'self': 'h'
    },
    'conscientiousness': {
        'articles': 'l',
        'negative_words': 'l',
        'negations': 'l',
        'tentative': 'h',
        'unique_words': 'h',
        'positive_words': 'h',
        'you': 'l',
        'swear':'l',
        'self': 'h',
        'preps': 'h'
    }
}

# %%
def get_personality(tbl, personality):
    result = []
    for i,r in tbl.iterrows():
        scores = []
        for k in personality.keys():
            if r[k].lower() == personality[k]:
                val = 1
            elif r[k].upper() == personality[k]:
                val = 2
            else: 
                val =0
            scores.append(val)
        result.append(np.mean(scores))
    return result

# %%
def get_classifications(tbl, personality):
    classifications = pd.DataFrame()
    for f in personality.keys():
        mean  = np.average(tbl[f])
        stddev = np.std(tbl[f])
        upper_thresh = mean+stddev
        lower_thresh = mean-stddev
        vals = []
        if personality[f] is 'h' :
            vals = tbl[f].map(lambda x: 2 if x  > upper_thresh  else 0)
        else :
            vals = tbl[f].map(lambda x: 2 if x  < lower_thresh  else 0)
        classifications[f] = vals
    return np.average(classifications, axis=1)

# %%
profile_person.columns
# Out:
# Index(['id', 'sent_count', 'qmarks', 'avg_nums', 'conj', 'brackets', 'self',
#        'foreign', 'avg_word_len', 'other_pro', 'pos_count', 'formality',
#        'prepositions', 'unique_words', 'articles', 'capital', 'exclaim', 'we',
#        'when', 'adverbs', 'negations', 'wc', 'adjectives', 'you', 'particles',
#        'i', 'verbs', 'interjections', 'modal', 'pronouns', 'avg_sent_len',
#        'stop', 'nouns', 'avg_long_words'],
#       dtype='object')

# %%
get_classifications(profile_person, personalities['neurotism'] )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'neg_words'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-92f0ee09dd8c> in <module>()
# ----> 1 get_classifications(profile_person, personalities['neurotism'] )
#
# <ipython-input-22-5652f52c9582> in get_classifications(tbl, personality)
#       2     classifications = pd.DataFrame()
#       3     for f in personality.keys():
# ----> 4         mean  = np.average(tbl[f])
#       5         stddev = np.std(tbl[f])
#       6         upper_thresh = mean+stddev
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1643         res = cache.get(item)
#    1644         if res is None:
# -> 1645             values = self._data.get(item)
#    1646             res = self._box_item_values(item, values)
#    1647             cache[item] = res
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
# -> 2444                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2445
#    2446         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'neg_words'

# %%
g_big_five = pd.DataFrame({'id': class_g_personality.id})

# %%
g_big_five['neurotism'] = get_personality(class_g_personality, personalities['neurotism'])
g_big_five['extraversion'] = get_personality(class_g_personality, personalities['extraversion'])
g_big_five['openness'] = get_personality(class_g_personality, personalities['openness'])
g_big_five['conscientiousness'] = get_personality(class_g_personality, personalities['conscientiousness'])
g_big_five['agreeableness'] = get_personality(class_g_personality, personalities['agreeableness'])

# %%
h_big_five = pd.DataFrame({'id': class_h_personality.id})

# %%
h_big_five['neurotism'] = get_personality(class_h_personality, personalities['neurotism'])
h_big_five['extraversion'] = get_personality(class_h_personality, personalities['extraversion'])
h_big_five['openness'] = get_personality(class_h_personality, personalities['openness'])
h_big_five['conscientiousness'] = get_personality(class_h_personality, personalities['conscientiousness'])
h_big_five['agreeableness'] = get_personality(class_h_personality, personalities['agreeableness'])

# %%
h_big_five['id'] = h_big_five['id'].astype(int)

# %% [markdown]
# ## Submitting values

# %%
h_personality['id'] = h_personality['id'].astype(int)

# %%
g_reviews = reviews[['id', 'reviewer_id']].join(g_big_five.set_index('id'), on ='reviewer_id')

# %%
h_reviews = reviews[['id', 'recipient_id']].join(h_big_five.set_index('id'), on ='recipient_id')

# %%
cols = set(h_reviews.columns) - set(['id', 'recipient_id', 'reviewer_id'])

# %%
result = pd.DataFrame({'id': list(reviews.id)})

# %%
len(result)
# Out:
# 215960

# %%
result[~result.neurotism.isnull()]
# Out:
#                id  agreeableness  extraversion  neurotism  openness  \
# 203        401808            0.2           0.1       0.00       0.2
# 204        425216            0.2           0.2       0.00       0.4
# 205        454928            0.2           0.0       0.00       0.0
# 206        475719            0.2           0.2       0.25       0.0
# 207        540860            0.0           0.4       0.00       0.2
# 208        582546            0.2           0.1       0.25       0.6
# 209        630702            0.0           0.2       0.25       0.0
# 210        644485            0.2           0.0       0.25       0.4
# 211        686637            0.4           0.0       0.25       0.2
# 213        740991            0.6           0.2       0.50       0.2
# 214        781890            0.2           0.1       0.50       0.2
# 215        798934            0.2           0.0       0.00       0.2
# 216        840106            0.4           0.1       0.25       0.4
# 217        852090            0.0           0.2       0.25       0.2
# 218        872866            0.0           0.1       0.25       0.2
# 219        878719            0.4           0.0       0.25       0.2
# 220        898648            0.0           0.2       0.00       0.2
# 221        908212            0.0           0.0       0.25       0.0
# 222        914970            0.0           0.1       0.00       0.2
# 224        930830            0.2           0.1       0.00       0.2
# 225        944380            0.2           0.3       0.00       0.2
# 226        975337            0.0           0.0       0.25       0.2
# 227        990349            0.2           0.1       0.25       0.4
# 228       1057618            0.2           0.1       0.75       0.2
# 229       1063889            0.2           0.2       0.25       0.2
# 230       1085205            0.2           0.2       0.00       0.8
# 231       1147766            0.2           0.1       0.00       0.8
# 232       1166685            0.4           0.1       0.50       0.6
# 233       1206476            0.0           0.0       0.00       0.4
# 234       1254529            0.0           0.2       0.75       0.0
# ...           ...            ...           ...        ...       ...
# 215581  109621228            0.2           0.5       0.25       0.0
# 215599  149472119            0.0           0.2       0.00       0.2
# 215608  266233460            0.0           0.1       0.25       0.0
# 215617  194884088            0.2           0.2       0.50       0.2
# 215624  109272528            0.2           0.1       0.50       0.2
# 215656  224240234            0.2           0.1       0.25       0.2
# 215658  140234375            0.4           0.5       0.25       0.2
# 215671  178986457            0.2           0.1       0.00       0.6
# 215675  244804199            0.2           0.1       0.00       0.2
# 215677  187214076            0.4           0.2       0.75       0.2
# 215688  190865524            0.2           0.1       0.25       0.2
# 215694  250583228            0.0           0.2       0.50       0.0
# 215701  200468118            0.0           0.1       0.25       0.4
# 215705  244346736            0.2           0.0       0.50       0.2
# 215711  218243840            0.4           0.4       0.25       0.0
# 215712  160329280            0.4           0.1       0.75       0.4
# 215721  241808704            0.2           0.2       0.25       0.2
# 215724  253501376            0.2           0.1       0.25       0.0
# 215732  176265038            0.2           0.3       0.25       0.2
# 215734  230641985            0.2           0.1       0.25       0.2
# 215735  144079616            0.2           0.1       0.00       0.4
# 215738  166481167            0.2           0.1       0.25       0.0
# 215744  153263538            0.2           0.1       0.25       0.2
# 215753  159725004            0.2           0.1       0.00       0.4
# 215768  228957620            0.2           0.1       0.25       0.0
# 215773  192548623            0.0           0.2       0.25       0.2
# 215776  259218646            0.2           0.1       0.25       0.0
# 215785  217091519            0.6           0.3       0.50       0.6
# 215835  213713854            0.0           0.1       0.25       0.0
# 215851  219447358            0.0           0.2       0.00       0.2
#
#         conscientiousness
# 203                   0.0
# 204                   0.0
# 205                   0.2
# 206                   0.4
# 207                   0.4
# 208                   0.4
# 209                   0.2
# 210                   0.2
# 211                   0.0
# 213                   0.2
# 214                   0.0
# 215                   0.2
# 216                   0.2
# 217                   0.0
# 218                   0.0
# 219                   0.2
# 220                   0.0
# 221                   0.0
# 222                   0.2
# 224                   0.2
# 225                   0.2
# 226                   0.0
# 227                   0.2
# 228                   0.2
# 229                   0.6
# 230                   0.8
# 231                   0.8
# 232                   0.2
# 233                   0.4
# 234                   0.0
# ...                   ...
# 215581                0.0
# 215599                0.0
# 215608                0.0
# 215617                0.2
# 215624                0.0
# 215656                0.2
# 215658                0.2
# 215671                0.6
# 215675                0.4
# 215677                0.0
# 215688                0.2
# 215694                0.0
# 215701                0.6
# 215705                0.4
# 215711                0.2
# 215712                0.2
# 215721                0.4
# 215724                0.4
# 215732                0.4
# 215734                0.2
# 215735                0.6
# 215738                0.4
# 215744                0.2
# 215753                0.6
# 215768                0.4
# 215773                0.6
# 215776                0.2
# 215785                0.2
# 215835                0.2
# 215851                0.2
#
# [93826 rows x 6 columns]

# %%
for c in cols: 
    result.is_copy = False
    result[str(c)] = np.abs(h_reviews[str(c)] - g_reviews[str(c)])

# %%
result[~result.neurotism.isnull()].to_csv('reviews_linguistic.csv')

# %%
profile_person = pd.read_csv('profile_linguistic.csv', index_col=0)

# %%
len(profile_person)
# Out:
# 46969

# %%
profile_person
# Out:
#                id  sent_count  qmarks  avg_nums      conj  brackets      self  \
# 203        401808         0.0     0.0  0.000000 -0.107843       0.0  0.000000
# 206        475719        -1.0     0.0  0.000000 -0.095023       0.0  0.000000
# 207        540860         0.0     0.0 -0.086957 -0.028133       0.0  0.000000
# 215599 -0.129825            0.0  0.017544  0.045263     -2.150000   1.0
# 215608 -0.111643            0.0 -0.012759  0.014354    -11.400000   3.0
# 215617 -0.113733            0.0  0.006050  0.059286    -23.400000   0.0
# 215835 -0.214575            0.0  0.015385  0.101215     -6.857143   4.0
#
#            nouns  avg_long_words
# 203    -0.098039       -0.029412
# 206     0.158371        0.393665
# 207     0.017903        0.383632
# 208     0.085688        0.281612
# 209    -0.364706        0.070588
# 210     0.050109        0.408860
# 211     0.235294        0.184874
# 213     0.030993        0.244782
# 214     0.130031        0.260062
# 217     0.170778        0.309298
# 218     0.028398        0.229209
# 219     0.064562        0.421808
# 222     0.124183        0.248366
# 227     0.062880        0.367140
# 228     0.079044        0.314338
# 229     0.098214        0.017857
# 231    -0.114286       -0.057143
# 232     0.024845       -0.335404
# 233     0.085714       -0.257143
# 235     0.058442       -0.038961
# 237     0.063492        0.059524
# 238     0.066202       -0.003484
# 239     0.285714        0.110599
# 240    -0.047619       -0.107143
# 242     0.035714       -0.857143
# 243     0.170960        0.077283
# 244     0.035714       -0.107143
# 245     0.174603       -0.079365
# 246     0.054945       -0.164835
# 247    -0.028571       -0.028571
# ...          ...             ...
# 214485  0.222222       -0.266667
# 214513 -0.027778        0.083333
# 214519  0.023779        0.154345
# 214521 -0.090278        0.177083
# 214579  0.051435        0.033892
# 214580  0.039795        0.005991
# 214581  0.133603       -0.114710
# 214588  0.043860       -0.307018
# 214589 -0.027846       -0.016320
# 214718 -0.034050       -0.050179
# 214838 -0.206764       -0.032962
# 214846 -0.044832       -0.035803
# 214848 -0.085236       -0.432268
# 214874  0.028058        0.137823
# 214901 -0.062851        0.065095
# 214944 -0.059354        0.093067
# 214973 -0.024906        0.055609
# 214989 -0.790123       -0.753086
# 214993  0.143210        0.113580
# 215108  0.126829       -0.043902
# 215123  0.026087        0.113043
# 215202 -0.006303       -0.009979
# 215208 -0.071429        0.008929
# 215326  0.178378        0.210811
# 215330  0.039489        0.016366
# 215578  0.280702       -0.236842
# 215599  0.060702        0.063158
# 215608  0.068581        0.202552
# 215617  0.073805        0.067756
# 215835  0.042105       -0.072065
#
# [46969 rows x 34 columns]

# %%
from watson_developer_cloud import WatsonApiException, PersonalityInsightsV3
import json 
try:
    # Invoke a Personality Insights method
    personality_insights = PersonalityInsightsV3(
        version='2017-10-13',
        username='a6897f4c-354d-4c0d-a998-1ffc367118b9',
        password='SPGpduAwCf24',
        url='https://gateway.watsonplatform.net/personality-insights/api'
    )
    
    with open('profile.txt') as personality_text:
        print(json.dumps(personality_insights.profile(content_type='text/plain', content=personality_text.read() ), indent=2))


except WatsonApiException as ex:
    print ("Method failed with status code " + str(ex.code) + ": " + ex.message)
# Out:
# {
#   "word_count": 314,
#   "word_count_message": "There were 314 words in the input. We need a minimum of 600, preferably 1,200 or more, to compute statistically significant estimates",
#   "processed_language": "en",
#   "personality": [
#     {
#       "trait_id": "big5_openness",
#       "name": "Openness",
#       "category": "personality",
#       "percentile": 0.9148457167873705,
#       "significant": true,
#       "children": [
#         {
#           "trait_id": "facet_adventurousness",
#           "name": "Adventurousness",
#           "category": "personality",
#           "percentile": 0.04811042796781162,
#           "significant": true
#         },
#         {
#           "trait_id": "facet_artistic_interests",
#           "name": "Artistic interests",
#           "category": "personality",
#           "percentile": 0.7356618254848829,
#           "significant": true
#         },
#         {
#           "trait_id": "facet_emotionality",
#           "name": "Emotionality",
#           "category": "personality",
#           "percentile": 0.7953062963665694,
#           "significant": true
#         },
#         {
#           "trait_id": "facet_imagination",
#           "name": "Imagination",
#           "category": "personality",
#           "percentile": 0.030294762790081642,
#           "significant": true
#         },
#         {
#           "trait_id": "facet_intellect",
#           "name": "Intellect",
#           "category": "personality",
#           "percentile": 0.7130302518017341,
#           "significant": true
#         },
#         {
#           "trait_id": "facet_liberalism",
#           "name": "Authority-challenging",
#           "category": "personality",
#           "percentile": 0.728422711033563,
#           "significant": true
#         }
#       ]
#     },
#     {
#       "trait_id": "big5_conscientiousness",
#       "name": "Conscientiousness",
#       "category": "personality",
#       "percentile": 0.6491085148545098,
#       "significant": true,
#       "children": [
#         {
#           "trait_id": "facet_achievement_striving",
#           "name": "Achievement striving",
#           "category": "personality",
#           "percentile": 0.7929232496072779,
#           "significant": true
#         },
#         {
#           "trait_id": "facet_cautiousness",
#           "name": "Cautiousness",
#           "category": "personality",
#           "percentile": 0.9742681278133134,
#           "significant": true
#         },
#         {
#           "trait_id": "facet_dutifulness",
#           "name": "Dutifulness",
#           "category": "personality",
#           "percentile": 0.9548451338381843,
#           "significant": true
#         },
#         {
#           "trait_id": "facet_orderliness",
#           "name": "Orderliness",
#           "category": "personality",
#           "percentile": 0.3178735379381294,
#           "significant": true
#         },
#         {
#           "trait_id": "facet_self_discipline",
#           "name": "Self-discipline",
#           "category": "personality",
#           "percentile": 0.7874026899167563,
#           "significant": true
#         },
#         {
#           "trait_id": "facet_self_efficacy",
#           "name": "Self-efficacy",
#           "category": "personality",
#           "percentile": 0.3869259257650962,
#           "significant": true
#         }
#       ]
#     },
#     {
#       "trait_id": "big5_extraversion",
#       "name": "Extraversion",
#       "category": "personality",
#       "percentile": 0.9844931387418474,
#       "significant": true,
#       "children": [
#         {
#           "trait_id": "facet_activity_level",
#           "name": "Activity level",
#           "category": "personality",
#           "percentile": 0.70778327135931,
#           "significant": true
#         },
#         {
#           "trait_id": "facet_assertiveness",
#           "name": "Assertiveness",
#           "category": "personality",
#           "percentile": 0.6525998444156094,
#           "significant": true
#         },
#         {
#           "trait_id": "facet_cheerfulness",
#           "name": "Cheerfulness",
#           "category": "personality",
#           "percentile": 0.5619071779184448,
#           "significant": true
#         },
#         {
#           "trait_id": "facet_excitement_seeking",
#           "name": "Excitement-seeking",
#           "category": "personality",
#           "percentile": 0.00161946587740186,
#           "significant": true
#         },
#         {
#           "trait_id": "facet_friendliness",
#           "name": "Outgoing",
#           "category": "personality",
#           "percentile": 0.8696492918705675,
#           "significant": true
#         },
#         {
#           "trait_id": "facet_gregariousness",
#           "name": "Gregariousness",
#           "category": "personality",
#           "percentile": 0.3202659851381018,
#           "significant": true
#         }
#       ]
#     },
#     {
#       "trait_id": "big5_agreeableness",
#       "name": "Agreeableness",
#       "category": "personality",
#       "percentile": 0.9859145639863955,
#       "significant": true,
#       "children": [
#         {
#           "trait_id": "facet_altruism",
#           "name": "Altruism",
#           "category": "personality",
#           "percentile": 0.9000797892844505,
#           "significant": true
#         },
#         {
#           "trait_id": "facet_cooperation",
#           "name": "Cooperation",
#           "category": "personality",
#           "percentile": 0.9996787469270836,
#           "significant": true
#         },
#         {
#           "trait_id": "facet_modesty",
#           "name": "Modesty",
#           "category": "personality",
#           "percentile": 0.6843932037596896,
#           "significant": true
#         },
#         {
#           "trait_id": "facet_morality",
#           "name": "Uncompromising",
#           "category": "personality",
#           "percentile": 0.9731731603661976,
#           "significant": true
#         },
#         {
#           "trait_id": "facet_sympathy",
#           "name": "Sympathy",
#           "category": "personality",
#           "percentile": 0.9877465341291249,
#           "significant": true
#         },
#         {
#           "trait_id": "facet_trust",
#           "name": "Trust",
#           "category": "personality",
#           "percentile": 0.9868746849772171,
#           "significant": true
#         }
#       ]
#     },
#     {
#       "trait_id": "big5_neuroticism",
#       "name": "Emotional range",
#       "category": "personality",
#       "percentile": 0.8277996517523803,
#       "significant": true,
#       "children": [
#         {
#           "trait_id": "facet_anger",
#           "name": "Fiery",
#           "category": "personality",
#           "percentile": 0.02352902211768476,
#           "significant": true
#         },
#         {
#           "trait_id": "facet_anxiety",
#           "name": "Prone to worry",
#           "category": "personality",
#           "percentile": 0.18981855555734717,
#           "significant": true
#         },
#         {
#           "trait_id": "facet_depression",
#           "name": "Melancholy",
#           "category": "personality",
#           "percentile": 0.1890764193721155,
#           "significant": true
#         },
#         {
#           "trait_id": "facet_immoderation",
#           "name": "Immoderation",
#           "category": "personality",
#           "percentile": 0.47426700930648846,
#           "significant": true
#         },
#         {
#           "trait_id": "facet_self_consciousness",
#           "name": "Self-consciousness",
#           "category": "personality",
#           "percentile": 0.05002076399278704,
#           "significant": true
#         },
#         {
#           "trait_id": "facet_vulnerability",
#           "name": "Susceptible to stress",
#           "category": "personality",
#           "percentile": 0.18920067432667925,
#           "significant": true
#         }
#       ]
#     }
#   ],
#   "needs": [
#     {
#       "trait_id": "need_challenge",
#       "name": "Challenge",
#       "category": "needs",
#       "percentile": 0.008306030357458416,
#       "significant": true
#     },
#     {
#       "trait_id": "need_closeness",
#       "name": "Closeness",
#       "category": "needs",
#       "percentile": 0.36928109063105785,
#       "significant": true
#     },
#     {
#       "trait_id": "need_curiosity",
#       "name": "Curiosity",
#       "category": "needs",
#       "percentile": 0.0008908380365653668,
#       "significant": true
#     },
#     {
#       "trait_id": "need_excitement",
#       "name": "Excitement",
#       "category": "needs",
#       "percentile": 1.7341754865951575e-05,
#       "significant": true
#     },
#     {
#       "trait_id": "need_harmony",
#       "name": "Harmony",
#       "category": "needs",
#       "percentile": 0.011634328345780709,
#       "significant": true
#     },
#     {
#       "trait_id": "need_ideal",
#       "name": "Ideal",
#       "category": "needs",
#       "percentile": 0.022016779195174196,
#       "significant": true
#     },
#     {
#       "trait_id": "need_liberty",
#       "name": "Liberty",
#       "category": "needs",
#       "percentile": 0.0005327411664511339,
#       "significant": true
#     },
#     {
#       "trait_id": "need_love",
#       "name": "Love",
#       "category": "needs",
#       "percentile": 0.16545826977821793,
#       "significant": true
#     },
#     {
#       "trait_id": "need_practicality",
#       "name": "Practicality",
#       "category": "needs",
#       "percentile": 0.002224305287131023,
#       "significant": true
#     },
#     {
#       "trait_id": "need_self_expression",
#       "name": "Self-expression",
#       "category": "needs",
#       "percentile": 0.002565748651311095,
#       "significant": true
#     },
#     {
#       "trait_id": "need_stability",
#       "name": "Stability",
#       "category": "needs",
#       "percentile": 0.10161268647778726,
#       "significant": true
#     },
#     {
#       "trait_id": "need_structure",
#       "name": "Structure",
#       "category": "needs",
#       "percentile": 0.030047572587723226,
#       "significant": true
#     }
#   ],
#   "values": [
#     {
#       "trait_id": "value_conservation",
#       "name": "Conservation",
#       "category": "values",
#       "percentile": 0.01003296528635339,
#       "significant": true
#     },
#     {
#       "trait_id": "value_openness_to_change",
#       "name": "Openness to change",
#       "category": "values",
#       "percentile": 0.012864167735589793,
#       "significant": true
#     },
#     {
#       "trait_id": "value_hedonism",
#       "name": "Hedonism",
#       "category": "values",
#       "percentile": 0.012024136209623504,
#       "significant": true
#     },
#     {
#       "trait_id": "value_self_enhancement",
#       "name": "Self-enhancement",
#       "category": "values",
#       "percentile": 0.00034509117353059837,
#       "significant": true
#     },
#     {
#       "trait_id": "value_self_transcendence",
#       "name": "Self-transcendence",
#       "category": "values",
#       "percentile": 0.10112446932761415,
#       "significant": true
#     }
#   ],
#   "warnings": [
#     {
#       "warning_id": "WORD_COUNT_MESSAGE",
#       "message": "There were 314 words in the input. We need a minimum of 600, preferably 1,200 or more, to compute statistically significant estimates"
#     }
#   ]
# }
